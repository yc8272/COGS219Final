# %%
#opening the water data from california water suppliers

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
file_open_path = 'clearinghouse_report.csv'

df = pd.read_csv(file_open_path)

# %%
df.head()
# Out:
#    ORG_ID     SUPPLIER_NAME WATER_SYSTEM_ID REPORT_PERIOD_START_DATE  \
# 0      13  City of Adelanto       CA3610001               2024-12-01
# 1      13  City of Adelanto       CA3610001               2024-11-01
# 2      13  City of Adelanto       CA3610001               2024-10-01
# 3      13  City of Adelanto       CA3610001               2024-09-01
# 4      13  City of Adelanto       CA3610001               2024-08-01
#
#   REPORT_PERIOD_END_DATE  POP_REPORT_PERIOD   DWR_STANDARD_LEVEL  \
# 0             2024-12-31              39930  2 (10-19% Shortage)
# 1             2024-11-30              39930  2 (10-19% Shortage)
# 2             2024-10-31              39930  2 (10-19% Shortage)
# 3             2024-09-30              39930  2 (10-19% Shortage)
# 4             2024-08-31              39930  2 (10-19% Shortage)
#
#   POTABLE_SUPPLY_UOM  POTABLE_SUPPLY_OU  POTABLE_SUPPLY_GAL  ...  \
# 0        Gallons (G)        130823576.0         130823576.0  ...
# ...

# %%
print(df.columns)
# Out:
# Index(['ORG_ID', 'SUPPLIER_NAME', 'WATER_SYSTEM_ID',
#        'REPORT_PERIOD_START_DATE', 'REPORT_PERIOD_END_DATE',
#        'POP_REPORT_PERIOD', 'DWR_STANDARD_LEVEL', 'POTABLE_SUPPLY_UOM',
#        'POTABLE_SUPPLY_OU', 'POTABLE_SUPPLY_GAL', 'POTABLE_SUPPLY_PRELIM_EST',
#        'POTABLE_DEMAND_UOM', 'POTABLE_VOL_SOLD_OU', 'POTABLE_VOL_SOLD_GAL',
#        'POTABLE_SUPPLY_MINUS_SOLD_GAL', 'POTABLE_DEMAND_RES_SF_OU',
#        'POTABLE_DEMAND_RES_MF_OU', 'POTABLE_DEMAND_RES_OU',
#        'POTABLE_DEMAND_RES_GAL', 'R-GPCD', 'POTABLE_DEMAND_RES_PRELIM_EST',
#        'POTABLE_DEMAND_AG_OU', 'POTABLE_DEMAND_AG_GAL', 'POTABLE_DEMAND_CI_OU',
#        'POTABLE_DEMAND_I_OU', 'POTABLE_DEMAND_CII_OU',
#        'POTABLE_DEMAND_CII_GAL', 'POTABLE_DEMAND_IRR_OU',
#        'POTABLE_DEMAND_IRR_GAL', 'POTABLE_DEMAND_O_OU', 'POTABLE_DEMAND_O_GAL',
#        'POTABLE_DEMAND_PRELIM_EST', 'NONPOTABLE_DEMAND_UOM',
#        'RES_RECYCLED_DEMAND_OU', 'NON_RES_RECYCLED_DEMAND_OU',
# ...
